# %% [markdown]
# # Generative Adverserial Networks in PyTorch
#
#   **Deep neural networks are used mainly for supervised learning: classification or regression.**
#
#   **Generative Adverserial Networks or GANs, however, use neural networks for a very different purpose: Generative modeling**
#
#   > Generative modeling is an unsupervised learning task in machine learning that involves automatically discovering and learning the regularities or patterns in input data in such a way that the model can be used to generate or output new examples that plausibly could have been drawn from the original dataset. - [Source](https://machinelearningmastery.com/what-are-generative-adversarial-networks-gans/)
#
#   **A Generative Adverserial Network takes the following approach:**
#
#   ![GAN Flowchart](https://i.imgur.com/6NMdO9u.png)
#
# *   **What is a GAN?**
#
#   **A GAN consists of two neural networks:**
#
#   **1. Generator (G):**
#
#       Generates "fake" data samples from random noise.
#       Example: Creates images of handwritten digits.
#
#   **2. Discriminator (D):**
#
#       **Tries to differentiate between "real" data samples (from the training set) and "fake" samples (from the generator).**
#       Example: Identifies whether an image of a digit is real or generated.
#       These two networks are trained together in a game-like scenario where:
#
#       The Generator tries to produce data that the Discriminator will incorrectly classify as real.
#       The Discriminator tries to correctly classify real and fake data.
#
#
#   * GANs however, can be difficult to train, and are extremely sensitive to hyperparameters, activation functions and regularization. In this tutorial, we'll train a GAN to generate images of handwritten digits similar to those from the MNIST database.
#
#   <img src="https://i.imgur.com/CAYnuo1.jpg" width="360" >
#
#
#
#   *** Define the problem statement**
#
#   1. Load the data (with transforms and normalization)
#     * Denormalize for visual inspection of samples
#   2. Define the Discriminator network
#     * Study the activation function: Leaky ReLU
#   3. Define the Generator network
#     * Explain the output activation function: TanH
#     * Look at some sample outputs
#   4. Define losses, optimizers and helper functions for training
#     * For discriminator
#     * For generator
#   5. Train the model
#     * Save intermediate generated images to file
#   6. Look at some outputs
#   7. Save the models

# %% [markdown]
# # 1. IMPORTING LIBRARIES AND DATASETS

# %%
import torch
import torchvision
from torchvision.transforms import ToTensor, Normalize, Compose
from torchvision.datasets import MNIST

mnist = MNIST(root='data',
              train=True,
              download=True,
              transform=Compose([ToTensor(), Normalize(mean=(0.5,), std=(0.5,))]))

# %% [markdown]
# Note that we are are transforming the pixel values from the range `[0, 1]` to the range `[-1, 1]`. The reason for doing this will become clear when define the generator network. Let's look at a sample tensor from the data.

# %%
img, label = mnist[0]
print('Label: ', label)
print(img[:,10:15,10:15])
torch.min(img), torch.max(img)
# Out:
# Label:  5
# tensor([[[-0.9922,  0.2078,  0.9843, -0.2941, -1.0000],
#          [-1.0000,  0.0902,  0.9843,  0.4902, -0.9843],
#          [-1.0000, -0.9137,  0.4902,  0.9843, -0.4510],
#          [-1.0000, -1.0000, -0.7255,  0.8902,  0.7647],
#          [-1.0000, -1.0000, -1.0000, -0.3647,  0.8824]]])
# (tensor(-1.), tensor(1.))

# %% [markdown]
# **As expected, the pixel values range from -1 to 1. Let's define a helper to denormalize and view the images. This function will also be useful for viewing the generated images.**

# %%
def denorm(x):
    out = (x + 1) / 2
    return out.clamp(0, 1)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

img_norm = denorm(img)
plt.imshow(img_norm[0], cmap='gray')
print('Label:', label)
# Out:
# Label: 5

# %% [markdown]
# Finally, let's create a dataloader to load the images in batches.

# %%
from torch.utils.data import DataLoader

batch_size = 100
data_loader = DataLoader(mnist, batch_size, shuffle=True)

# %%
for img_batch, label_batch in data_loader:
    print('first batch')
    print(img_batch.shape)
    plt.imshow(img_batch[0][0], cmap='gray')
    print(label_batch)
    break
# Out:
# first batch
# torch.Size([100, 1, 28, 28])
# tensor([5, 8, 6, 2, 1, 3, 3, 8, 9, 6, 0, 1, 8, 5, 6, 5, 0, 1, 1, 4, 6, 0, 0, 1,
#         9, 0, 1, 7, 9, 8, 8, 3, 8, 1, 8, 3, 5, 5, 0, 0, 4, 3, 9, 8, 1, 6, 8, 0,
#         8, 6, 8, 5, 2, 3, 4, 8, 4, 5, 3, 4, 7, 5, 3, 8, 5, 4, 3, 3, 8, 9, 1, 4,
#         5, 9, 1, 2, 1, 0, 5, 7, 4, 8, 2, 5, 1, 7, 4, 0, 2, 8, 0, 0, 6, 5, 1, 1,
#         2, 1, 5, 9])

# %% [markdown]
# We'll also create a `device` which can be used to move the data and models to a GPU, if one is available.

# %%
# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cpu')

# %% [markdown]
# # 2. Discriminator Network
#
# The discriminator takes an image as input, and tries to classify it as "real" or "generated". In this sense, it's like any other neural network. While we can use a CNN for the discriminator, we'll use a simple feedforward network with 3 linear layers to keep things since. We'll treat each 28x28 image as a vector of size 784.

# %%
image_size = 784
hidden_size = 256

# %%
import torch.nn as nn

D = nn.Sequential(
    nn.Linear(image_size, hidden_size),
    nn.LeakyReLU(0.2),
    nn.Linear(hidden_size, hidden_size),
    nn.LeakyReLU(0.2),
    nn.Linear(hidden_size, 1),
    nn.Sigmoid())

# %% [markdown]
# **We use the Leaky ReLU activation for the discriminator.**
#
# <img src="https://cdn-images-1.medium.com/max/1600/1*ypsvQH7kvtI2BhzR2eT_Sw.png" width="420">
#
#
# >  Different from the regular ReLU function, Leaky ReLU allows the pass of a small gradient signal for negative values. As a result, it makes the gradients from the discriminator flows stronger into the generator. Instead of passing a gradient (slope) of 0 in the back-prop pass, it passes a small negative gradient.  - [Source](https://sthalles.github.io/advanced_gans/)
#
# **Just like any other binary classification model, the output of the discriminator is a single number between 0 and 1,** which can be interpreted as the probability of the input image being fake i.e. generated.
#
# Let's move the discriminator model to the chosen device.

# %%
D.to(device);

# %% [markdown]
# ## Generator Network
#
# **The input to the generator is typically a vector or a matrix which is used as a seed for generating an image.** Once again, to keep things simple, we'll use a feedfoward neural network with 3 layers, and the output will be a vector of size 784, which can be transformed to a 28x28 px image.\

# %%
latent_size = 64
G = nn.Sequential(
    nn.Linear(latent_size, hidden_size),
    nn.ReLU(),
    nn.Linear(hidden_size, hidden_size),
    nn.ReLU(),
    nn.Linear(hidden_size, image_size),
    nn.Tanh())

# %% [markdown]
# We use the TanH activation function for the output layer of the generator.
#
# <img src="https://nic.schraudolph.org/teach/NNcourse/figs/tanh.gif" width="420" >
#
# > "The ReLU activation (Nair & Hinton, 2010) is used in the generator with the exception of the output layer which uses the Tanh function. We observed that using a bounded activation allowed the model to learn more quickly to saturate and cover the color space of the training distribution. Within the discriminator we found the leaky rectified activation (Maas et al., 2013) (Xu et al., 2015) to work well, especially for higher resolution modeling." - [Source](https://stackoverflow.com/questions/41489907/generative-adversarial-networks-tanh)
#
#
# Note that since the outputs of the TanH activation lie in the range `[-1,1]`, we have applied the same transformation to the images in the training dataset. Let's generate an output vector using the generator and view it as an image by transforming and denormalizing the output.

# %%
y = G(torch.randn(2, latent_size))
gen_imgs = denorm(y.reshape((-1, 28,28)).detach())

# %%
plt.imshow(gen_imgs[0], cmap='gray');

# %%
plt.imshow(gen_imgs[1], cmap='gray');

# %%
G.to(device);

# %% [markdown]
# ## Discriminator Training
#
# **Since the discriminator is a binary classification model**, we can use the binary cross entropy loss function to quantify how well it is able to **differentiate between real and generated images**.
#
# <img src="https://image.slidesharecdn.com/chrishokamp-dublinnlp3-160805110319/95/task-based-learning-for-nlp-going-beyond-cross-entropy-chris-hokamp-10-638.jpg?cb=1470395213" width="420" >

# %%
criterion = nn.BCELoss()
d_optimizer = torch.optim.Adam(D.parameters(), lr=0.0002)

# %% [markdown]
# Let's **define helper functions to reset gradients and  train the discriminator.**

# %%
def reset_grad():
    d_optimizer.zero_grad()
    g_optimizer.zero_grad()

def train_discriminator(images):
    # Create the labels which are later used as input for the BCE loss
    real_labels = torch.ones(batch_size, 1).to(device)
    fake_labels = torch.zeros(batch_size, 1).to(device)

    # Loss for real images
    outputs = D(images)
    d_loss_real = criterion(outputs, real_labels)
    real_score = outputs

    # Loss for fake images
    z = torch.randn(batch_size, latent_size).to(device)
    fake_images = G(z)
    outputs = D(fake_images)
    d_loss_fake = criterion(outputs, fake_labels)
    fake_score = outputs

    # Combine losses
    d_loss = d_loss_real + d_loss_fake
    # Reset gradients
    reset_grad()
    # Compute gradients
    d_loss.backward()
    # Adjust the parameters using backprop
    d_optimizer.step()

    return d_loss, real_score, fake_score

# %% [markdown]
# Here are the steps involved in training the discriminator.
#
# - We expect the discriminator to output 1 if the image was picked from the real MNIST dataset, and 0 if it was generated.
#
# - We first pass a batch of real images, and compute the loss, setting the target labels to 1.
#
# - Then, we generate a batch of fake images using the generator, pass them into the discriminator, and compute the loss, setting the target labels to 0.
#
# - Finally we add the two losses and use the overall loss to perform gradient descent to adjust the weights of the discriminator.
#
# It's important to note that we don't change the weights of the generator model while training the discriminator (`d_optimizer` only affects the `D.parameters()`)

# %% [markdown]
# ## Generator Training
#
# Since the outputs of the generator are images, it's not obvious how we can train the generator. This is where we employ a rather elegant trick, which is to use the discriminator as a part of the loss function. Here's how it works:
#
# - **We generate a batch of images using the generator, pass the into the discriminator.**
#
# - **We calculate the loss by setting the target labels to 1 i.e. real. We do this because the generator's objective is to "fool" the discriminator.**
#
# - **We use the loss to perform gradient descent i.e. change the weights of the generator, so it gets better at generating real-like images.**
#
# Here's what this looks like in code.

# %%
g_optimizer = torch.optim.Adam(G.parameters(), lr=0.0002)

# %%
def train_generator():
    # Generate fake images and calculate loss
    z = torch.randn(batch_size, latent_size).to(device)
    fake_images = G(z)
    labels = torch.ones(batch_size, 1).to(device)
    g_loss = criterion(D(fake_images), labels)

    # Backprop and optimize
    reset_grad()
    g_loss.backward()
    g_optimizer.step()
    return g_loss, fake_images

# %% [markdown]
# ## Training the Model and Ouput
#
# Let's create a directory where we can save intermediate outputs from the generator to visually inspect the progress of the model

# %%
import os

sample_dir = 'samples'
if not os.path.exists(sample_dir):
    os.makedirs(sample_dir)

# %% [markdown]
# **Let's save a batch of real images that we can use for visual comparision while looking at the generated images.**

# %%
from IPython.display import Image
from torchvision.utils import save_image

# Save some real images
for images, _ in data_loader:
    images = images.reshape(images.size(0), 1, 28, 28)
    save_image(denorm(images), os.path.join(sample_dir, 'real_images.png'), nrow=10)
    break

Image(os.path.join(sample_dir, 'real_images.png'))

# %% [markdown]
# We'll also define a helper function to save a batch of generated images to disk at the end of every epoch. We'll use a fixed set of input vectors to the generator to see how the individual generated images evolve over time as we train the model.

# %%
sample_vectors = torch.randn(batch_size, latent_size).to(device)

def save_fake_images(index):
    fake_images = G(sample_vectors)
    fake_images = fake_images.reshape(fake_images.size(0), 1, 28, 28)
    fake_fname = 'fake_images-{0:0=4d}.png'.format(index)
    print('Saving', fake_fname)
    save_image(denorm(fake_images), os.path.join(sample_dir, fake_fname), nrow=10)

# Before training
save_fake_images(0)
Image(os.path.join(sample_dir, 'fake_images-0000.png'))
# Out:
# Saving fake_images-0000.png

# %% [markdown]
# **We are now ready to train the model. In each epoch, we train the discriminator first, and then the generator. The training might take a while if you're not using a GPU.**

# %%
# %%time

num_epochs = 110
total_step = len(data_loader)
d_losses, g_losses, real_scores, fake_scores = [], [], [], []

for epoch in range(num_epochs):
    for i, (images, _) in enumerate(data_loader):
        # Load a batch & transform to vectors
        images = images.reshape(batch_size, -1).to(device)

        # Train the discriminator and generator
        d_loss, real_score, fake_score = train_discriminator(images)
        g_loss, fake_images = train_generator()

        # Inspect the losses
        if (i+1) % 200 == 0:
            d_losses.append(d_loss.item())
            g_losses.append(g_loss.item())
            real_scores.append(real_score.mean().item())
            fake_scores.append(fake_score.mean().item())
            print('Epoch [{}/{}], Step [{}/{}], d_loss: {:.4f}, g_loss: {:.4f}, D(x): {:.2f}, D(G(z)): {:.2f}'
                  .format(epoch, num_epochs, i+1, total_step, d_loss.item(), g_loss.item(),
                          real_score.mean().item(), fake_score.mean().item()))

    # Sample and save images
    save_fake_images(epoch+1)
# Out:
# Epoch [0/110], Step [200/600], d_loss: 0.3974, g_loss: 3.0140, D(x): 0.88, D(G(z)): 0.14
# Epoch [0/110], Step [400/600], d_loss: 0.4279, g_loss: 2.9532, D(x): 0.87, D(G(z)): 0.17
# Epoch [0/110], Step [600/600], d_loss: 0.4856, g_loss: 3.4386, D(x): 0.82, D(G(z)): 0.10
# Saving fake_images-0001.png
# Epoch [1/110], Step [200/600], d_loss: 0.5190, g_loss: 2.6224, D(x): 0.85, D(G(z)): 0.17
# Epoch [1/110], Step [400/600], d_loss: 0.3092, g_loss: 3.0984, D(x): 0.89, D(G(z)): 0.11
# Epoch [1/110], Step [600/600], d_loss: 0.5696, g_loss: 2.9470, D(x): 0.87, D(G(z)): 0.22
# Saving fake_images-0002.png
# Epoch [2/110], Step [200/600], d_loss: 0.4476, g_loss: 3.2401, D(x): 0.87, D(G(z)): 0.17
# Epoch [2/110], Step [400/600], d_loss: 0.5792, g_loss: 2.0428, D(x): 0.86, D(G(z)): 0.24
# Epoch [2/110], Step [600/600], d_loss: 0.5798, g_loss: 2.3615, D(x): 0.86, D(G(z)): 0.24
# Saving fake_images-0003.png
# Epoch [3/110], Step [200/600], d_loss: 0.5988, g_loss: 2.9261, D(x): 0.77, D(G(z)): 0.13
# Epoch [3/110], Step [400/600], d_loss: 0.7430, g_loss: 2.7064, D(x): 0.85, D(G(z)): 0.30
# Epoch [3/110], Step [600/600], d_loss: 0.5856, g_loss: 2.8205, D(x): 0.80, D(G(z)): 0.15
# Saving fake_images-0004.png
# Epoch [4/110], Step [200/600], d_loss: 0.4695, g_loss: 2.6534, D(x): 0.86, D(G(z)): 0.15
# Epoch [4/110], Step [400/600], d_loss: 0.5229, g_loss: 2.8235, D(x): 0.86, D(G(z)): 0.21
# Epoch [4/110], Step [600/600], d_loss: 0.6507, g_loss: 3.2035, D(x): 0.82, D(G(z)): 0.17
# Saving fake_images-0005.png
# Epoch [5/110], Step [200/600], d_loss: 0.3757, g_loss: 2.4828, D(x): 0.86, D(G(z)): 0.12
# Epoch [5/110], Step [400/600], d_loss: 0.5949, g_loss: 2.5057, D(x): 0.86, D(G(z)): 0.24
# Epoch [5/110], Step [600/600], d_loss: 0.6738, g_loss: 3.1285, D(x): 0.89, D(G(z)): 0.28
# Saving fake_images-0006.png
# Epoch [6/110], Step [200/600], d_loss: 0.4025, g_loss: 3.4308, D(x): 0.84, D(G(z)): 0.08
# Epoch [6/110], Step [400/600], d_loss: 0.6850, g_loss: 3.4968, D(x): 0.73, D(G(z)): 0.07
# Epoch [6/110], Step [600/600], d_loss: 0.7586, g_loss: 2.9411, D(x): 0.87, D(G(z)): 0.32
# Saving fake_images-0007.png
# Epoch [7/110], Step [200/600], d_loss: 0.4504, g_loss: 3.1426, D(x): 0.84, D(G(z)): 0.13
# Epoch [7/110], Step [400/600], d_loss: 0.5756, g_loss: 3.1827, D(x): 0.81, D(G(z)): 0.17
# Epoch [7/110], Step [600/600], d_loss: 0.4753, g_loss: 2.0052, D(x): 0.88, D(G(z)): 0.19
# Saving fake_images-0008.png
# Epoch [8/110], Step [200/600], d_loss: 0.5500, g_loss: 2.4403, D(x): 0.78, D(G(z)): 0.11
# Epoch [8/110], Step [400/600], d_loss: 0.4275, g_loss: 2.9876, D(x): 0.85, D(G(z)): 0.10
# Epoch [8/110], Step [600/600], d_loss: 0.5245, g_loss: 2.6866, D(x): 0.88, D(G(z)): 0.24
# Saving fake_images-0009.png
# Epoch [9/110], Step [200/600], d_loss: 0.5921, g_loss: 2.5676, D(x): 0.79, D(G(z)): 0.15
# Epoch [9/110], Step [400/600], d_loss: 0.5340, g_loss: 3.1134, D(x): 0.84, D(G(z)): 0.20
# Epoch [9/110], Step [600/600], d_loss: 0.4409, g_loss: 2.1017, D(x): 0.82, D(G(z)): 0.10
# Saving fake_images-0010.png
# Epoch [10/110], Step [200/600], d_loss: 0.5625, g_loss: 2.4957, D(x): 0.83, D(G(z)): 0.21
# Epoch [10/110], Step [400/600], d_loss: 0.7047, g_loss: 2.1965, D(x): 0.86, D(G(z)): 0.29
# Epoch [10/110], Step [600/600], d_loss: 0.6476, g_loss: 2.2549, D(x): 0.77, D(G(z)): 0.15
# Saving fake_images-0011.png
# Epoch [11/110], Step [200/600], d_loss: 0.6854, g_loss: 2.5301, D(x): 0.82, D(G(z)): 0.22
# Epoch [11/110], Step [400/600], d_loss: 0.6142, g_loss: 2.6224, D(x): 0.85, D(G(z)): 0.24
# Epoch [11/110], Step [600/600], d_loss: 0.6159, g_loss: 1.7889, D(x): 0.83, D(G(z)): 0.25
# Saving fake_images-0012.png
# Epoch [12/110], Step [200/600], d_loss: 0.5879, g_loss: 2.2547, D(x): 0.90, D(G(z)): 0.26
# Epoch [12/110], Step [400/600], d_loss: 0.5276, g_loss: 2.3689, D(x): 0.84, D(G(z)): 0.19
# Epoch [12/110], Step [600/600], d_loss: 0.8913, g_loss: 2.5199, D(x): 0.82, D(G(z)): 0.35
# Saving fake_images-0013.png
# Epoch [13/110], Step [200/600], d_loss: 0.5002, g_loss: 2.7852, D(x): 0.83, D(G(z)): 0.15
# Epoch [13/110], Step [400/600], d_loss: 0.6533, g_loss: 2.2545, D(x): 0.83, D(G(z)): 0.23
# Epoch [13/110], Step [600/600], d_loss: 0.5786, g_loss: 2.3404, D(x): 0.81, D(G(z)): 0.21
# Saving fake_images-0014.png
# Epoch [14/110], Step [200/600], d_loss: 0.6507, g_loss: 2.5048, D(x): 0.81, D(G(z)): 0.21
# Epoch [14/110], Step [400/600], d_loss: 0.6073, g_loss: 1.8926, D(x): 0.84, D(G(z)): 0.23
# Epoch [14/110], Step [600/600], d_loss: 0.4847, g_loss: 3.3633, D(x): 0.83, D(G(z)): 0.17
# Saving fake_images-0015.png
# Epoch [15/110], Step [200/600], d_loss: 0.6525, g_loss: 2.2670, D(x): 0.84, D(G(z)): 0.24
# Epoch [15/110], Step [400/600], d_loss: 0.5772, g_loss: 2.7948, D(x): 0.85, D(G(z)): 0.23
# Epoch [15/110], Step [600/600], d_loss: 0.4572, g_loss: 2.5487, D(x): 0.80, D(G(z)): 0.12
# Saving fake_images-0016.png
# Epoch [16/110], Step [200/600], d_loss: 0.6827, g_loss: 2.4275, D(x): 0.83, D(G(z)): 0.28
# Epoch [16/110], Step [400/600], d_loss: 0.4660, g_loss: 2.4125, D(x): 0.84, D(G(z)): 0.16
# Epoch [16/110], Step [600/600], d_loss: 0.6091, g_loss: 2.0305, D(x): 0.85, D(G(z)): 0.22
# Saving fake_images-0017.png
# Epoch [17/110], Step [200/600], d_loss: 1.0405, g_loss: 2.1260, D(x): 0.78, D(G(z)): 0.39
# Epoch [17/110], Step [400/600], d_loss: 0.5682, g_loss: 3.0488, D(x): 0.83, D(G(z)): 0.22
# Epoch [17/110], Step [600/600], d_loss: 0.4570, g_loss: 2.8246, D(x): 0.83, D(G(z)): 0.13
# Saving fake_images-0018.png
# Epoch [18/110], Step [200/600], d_loss: 0.8040, g_loss: 2.5381, D(x): 0.68, D(G(z)): 0.12
# Epoch [18/110], Step [400/600], d_loss: 0.7048, g_loss: 2.2939, D(x): 0.80, D(G(z)): 0.25
# Epoch [18/110], Step [600/600], d_loss: 0.5115, g_loss: 2.3352, D(x): 0.87, D(G(z)): 0.22
# Saving fake_images-0019.png
# Epoch [19/110], Step [200/600], d_loss: 0.7203, g_loss: 2.7052, D(x): 0.79, D(G(z)): 0.21
# Epoch [19/110], Step [400/600], d_loss: 0.6673, g_loss: 2.7086, D(x): 0.86, D(G(z)): 0.29
# Epoch [19/110], Step [600/600], d_loss: 0.7287, g_loss: 2.1293, D(x): 0.91, D(G(z)): 0.33
# Saving fake_images-0020.png
# Epoch [20/110], Step [200/600], d_loss: 0.6841, g_loss: 2.1982, D(x): 0.81, D(G(z)): 0.24
# Epoch [20/110], Step [400/600], d_loss: 0.5769, g_loss: 3.4665, D(x): 0.81, D(G(z)): 0.17
# Epoch [20/110], Step [600/600], d_loss: 0.9536, g_loss: 2.1318, D(x): 0.65, D(G(z)): 0.14
# Saving fake_images-0021.png
# Epoch [21/110], Step [200/600], d_loss: 0.3957, g_loss: 2.5009, D(x): 0.87, D(G(z)): 0.15
# Epoch [21/110], Step [400/600], d_loss: 0.7808, g_loss: 3.6871, D(x): 0.72, D(G(z)): 0.10
# Epoch [21/110], Step [600/600], d_loss: 0.6859, g_loss: 3.0107, D(x): 0.81, D(G(z)): 0.26
# Saving fake_images-0022.png
# Epoch [22/110], Step [200/600], d_loss: 0.5967, g_loss: 2.9500, D(x): 0.76, D(G(z)): 0.14
# Epoch [22/110], Step [400/600], d_loss: 0.6939, g_loss: 3.1457, D(x): 0.75, D(G(z)): 0.16
# Epoch [22/110], Step [600/600], d_loss: 0.5856, g_loss: 2.6408, D(x): 0.84, D(G(z)): 0.20
# Saving fake_images-0023.png
# Epoch [23/110], Step [200/600], d_loss: 0.9202, g_loss: 2.2139, D(x): 0.70, D(G(z)): 0.22
# Epoch [23/110], Step [400/600], d_loss: 0.8187, g_loss: 2.1358, D(x): 0.76, D(G(z)): 0.26
# Epoch [23/110], Step [600/600], d_loss: 0.6184, g_loss: 3.0270, D(x): 0.72, D(G(z)): 0.08
# Saving fake_images-0024.png
# Epoch [24/110], Step [200/600], d_loss: 0.5400, g_loss: 2.6807, D(x): 0.84, D(G(z)): 0.20
# Epoch [24/110], Step [400/600], d_loss: 0.5740, g_loss: 2.6672, D(x): 0.79, D(G(z)): 0.16
# Epoch [24/110], Step [600/600], d_loss: 0.5218, g_loss: 2.0514, D(x): 0.83, D(G(z)): 0.20
# Saving fake_images-0025.png
# Epoch [25/110], Step [200/600], d_loss: 0.7362, g_loss: 2.1979, D(x): 0.76, D(G(z)): 0.24
# Epoch [25/110], Step [400/600], d_loss: 0.6140, g_loss: 2.4358, D(x): 0.81, D(G(z)): 0.17
# Epoch [25/110], Step [600/600], d_loss: 0.6431, g_loss: 2.4765, D(x): 0.84, D(G(z)): 0.27
# Saving fake_images-0026.png
# Epoch [26/110], Step [200/600], d_loss: 0.8608, g_loss: 2.2502, D(x): 0.78, D(G(z)): 0.32
# Epoch [26/110], Step [400/600], d_loss: 1.0078, g_loss: 1.5484, D(x): 0.70, D(G(z)): 0.30
# Epoch [26/110], Step [600/600], d_loss: 0.6557, g_loss: 2.5142, D(x): 0.81, D(G(z)): 0.25
# Saving fake_images-0027.png
# Epoch [27/110], Step [200/600], d_loss: 0.7012, g_loss: 2.1847, D(x): 0.85, D(G(z)): 0.31
# Epoch [27/110], Step [400/600], d_loss: 0.6823, g_loss: 2.1968, D(x): 0.86, D(G(z)): 0.30
# Epoch [27/110], Step [600/600], d_loss: 0.7393, g_loss: 2.5696, D(x): 0.80, D(G(z)): 0.28
# Saving fake_images-0028.png
# Epoch [28/110], Step [200/600], d_loss: 0.6932, g_loss: 2.2697, D(x): 0.85, D(G(z)): 0.31
# Epoch [28/110], Step [400/600], d_loss: 0.6492, g_loss: 2.2516, D(x): 0.77, D(G(z)): 0.20
# Epoch [28/110], Step [600/600], d_loss: 0.5018, g_loss: 2.4509, D(x): 0.80, D(G(z)): 0.16
# Saving fake_images-0029.png
# Epoch [29/110], Step [200/600], d_loss: 0.6002, g_loss: 1.8074, D(x): 0.84, D(G(z)): 0.25
# Epoch [29/110], Step [400/600], d_loss: 0.7971, g_loss: 2.7041, D(x): 0.77, D(G(z)): 0.29
# Epoch [29/110], Step [600/600], d_loss: 0.5708, g_loss: 3.1555, D(x): 0.79, D(G(z)): 0.17
# Saving fake_images-0030.png
# Epoch [30/110], Step [200/600], d_loss: 0.4784, g_loss: 1.7765, D(x): 0.84, D(G(z)): 0.20
# Epoch [30/110], Step [400/600], d_loss: 0.7845, g_loss: 2.6317, D(x): 0.75, D(G(z)): 0.23
# Epoch [30/110], Step [600/600], d_loss: 1.1017, g_loss: 1.4698, D(x): 0.61, D(G(z)): 0.21
# Saving fake_images-0031.png
# Epoch [31/110], Step [200/600], d_loss: 0.6424, g_loss: 2.2868, D(x): 0.76, D(G(z)): 0.20
# Epoch [31/110], Step [400/600], d_loss: 0.6328, g_loss: 2.2530, D(x): 0.78, D(G(z)): 0.19
# Epoch [31/110], Step [600/600], d_loss: 0.6438, g_loss: 1.8062, D(x): 0.79, D(G(z)): 0.22
# Saving fake_images-0032.png
# Epoch [32/110], Step [200/600], d_loss: 0.5945, g_loss: 2.1810, D(x): 0.81, D(G(z)): 0.19
# Epoch [32/110], Step [400/600], d_loss: 0.7673, g_loss: 2.2103, D(x): 0.72, D(G(z)): 0.18
# Epoch [32/110], Step [600/600], d_loss: 0.6609, g_loss: 1.7045, D(x): 0.81, D(G(z)): 0.25
# Saving fake_images-0033.png
# Epoch [33/110], Step [200/600], d_loss: 0.7920, g_loss: 2.3864, D(x): 0.74, D(G(z)): 0.25
# Epoch [33/110], Step [400/600], d_loss: 0.6941, g_loss: 1.7878, D(x): 0.78, D(G(z)): 0.21
# Epoch [33/110], Step [600/600], d_loss: 0.8494, g_loss: 2.3121, D(x): 0.78, D(G(z)): 0.34
# Saving fake_images-0034.png
# Epoch [34/110], Step [200/600], d_loss: 0.6074, g_loss: 2.9770, D(x): 0.81, D(G(z)): 0.22
# Epoch [34/110], Step [400/600], d_loss: 0.6413, g_loss: 2.3228, D(x): 0.76, D(G(z)): 0.14
# Epoch [34/110], Step [600/600], d_loss: 0.3471, g_loss: 2.4314, D(x): 0.88, D(G(z)): 0.14
# Saving fake_images-0035.png
# Epoch [35/110], Step [200/600], d_loss: 0.6519, g_loss: 2.0677, D(x): 0.77, D(G(z)): 0.18
# Epoch [35/110], Step [400/600], d_loss: 0.8235, g_loss: 2.4474, D(x): 0.82, D(G(z)): 0.32
# Epoch [35/110], Step [600/600], d_loss: 0.5399, g_loss: 2.6721, D(x): 0.79, D(G(z)): 0.13
# Saving fake_images-0036.png
# Epoch [36/110], Step [200/600], d_loss: 0.9396, g_loss: 2.3013, D(x): 0.81, D(G(z)): 0.37
# Epoch [36/110], Step [400/600], d_loss: 0.6531, g_loss: 2.6371, D(x): 0.80, D(G(z)): 0.23
# Epoch [36/110], Step [600/600], d_loss: 0.8547, g_loss: 2.5373, D(x): 0.70, D(G(z)): 0.19
# Saving fake_images-0037.png
# Epoch [37/110], Step [200/600], d_loss: 0.9406, g_loss: 2.1920, D(x): 0.74, D(G(z)): 0.30
# Epoch [37/110], Step [400/600], d_loss: 0.8066, g_loss: 2.6361, D(x): 0.66, D(G(z)): 0.15
# Epoch [37/110], Step [600/600], d_loss: 0.7836, g_loss: 1.9218, D(x): 0.75, D(G(z)): 0.24
# Saving fake_images-0038.png
# Epoch [38/110], Step [200/600], d_loss: 0.9166, g_loss: 2.3749, D(x): 0.65, D(G(z)): 0.15
# Epoch [38/110], Step [400/600], d_loss: 1.0137, g_loss: 1.9371, D(x): 0.71, D(G(z)): 0.29
# Epoch [38/110], Step [600/600], d_loss: 0.9358, g_loss: 2.3676, D(x): 0.62, D(G(z)): 0.12
# Saving fake_images-0039.png
# Epoch [39/110], Step [200/600], d_loss: 0.9872, g_loss: 1.7819, D(x): 0.76, D(G(z)): 0.31
# Epoch [39/110], Step [400/600], d_loss: 0.7361, g_loss: 1.6193, D(x): 0.85, D(G(z)): 0.32
# Epoch [39/110], Step [600/600], d_loss: 0.9190, g_loss: 2.1381, D(x): 0.72, D(G(z)): 0.26
# Saving fake_images-0040.png
# Epoch [40/110], Step [200/600], d_loss: 0.6574, g_loss: 2.0716, D(x): 0.80, D(G(z)): 0.24
# Epoch [40/110], Step [400/600], d_loss: 0.7503, g_loss: 1.9216, D(x): 0.84, D(G(z)): 0.32
# Epoch [40/110], Step [600/600], d_loss: 0.5416, g_loss: 2.4317, D(x): 0.79, D(G(z)): 0.15
# Saving fake_images-0041.png
# Epoch [41/110], Step [200/600], d_loss: 0.5944, g_loss: 2.9111, D(x): 0.74, D(G(z)): 0.14
# Epoch [41/110], Step [400/600], d_loss: 1.0366, g_loss: 1.7502, D(x): 0.74, D(G(z)): 0.34
# Epoch [41/110], Step [600/600], d_loss: 0.7242, g_loss: 1.9260, D(x): 0.74, D(G(z)): 0.23
# Saving fake_images-0042.png
# Epoch [42/110], Step [200/600], d_loss: 0.7631, g_loss: 2.0999, D(x): 0.68, D(G(z)): 0.17
# Epoch [42/110], Step [400/600], d_loss: 0.8485, g_loss: 1.9422, D(x): 0.78, D(G(z)): 0.31
# Epoch [42/110], Step [600/600], d_loss: 0.6656, g_loss: 1.9534, D(x): 0.79, D(G(z)): 0.22
# Saving fake_images-0043.png
# Epoch [43/110], Step [200/600], d_loss: 0.5276, g_loss: 2.1898, D(x): 0.82, D(G(z)): 0.18
# Epoch [43/110], Step [400/600], d_loss: 0.5492, g_loss: 2.4070, D(x): 0.78, D(G(z)): 0.16
# Epoch [43/110], Step [600/600], d_loss: 0.6168, g_loss: 2.0224, D(x): 0.80, D(G(z)): 0.23
# Saving fake_images-0044.png
# Epoch [44/110], Step [200/600], d_loss: 0.6337, g_loss: 2.1772, D(x): 0.76, D(G(z)): 0.16
# Epoch [44/110], Step [400/600], d_loss: 0.8024, g_loss: 2.0181, D(x): 0.75, D(G(z)): 0.23
# Epoch [44/110], Step [600/600], d_loss: 1.0733, g_loss: 1.5637, D(x): 0.75, D(G(z)): 0.40
# Saving fake_images-0045.png
# Epoch [45/110], Step [200/600], d_loss: 0.6584, g_loss: 2.0585, D(x): 0.79, D(G(z)): 0.22
# Epoch [45/110], Step [400/600], d_loss: 1.0083, g_loss: 2.2017, D(x): 0.71, D(G(z)): 0.29
# Epoch [45/110], Step [600/600], d_loss: 0.9052, g_loss: 1.6234, D(x): 0.71, D(G(z)): 0.27
# Saving fake_images-0046.png
# Epoch [46/110], Step [200/600], d_loss: 0.7002, g_loss: 2.2498, D(x): 0.75, D(G(z)): 0.25
# Epoch [46/110], Step [400/600], d_loss: 0.7880, g_loss: 2.0200, D(x): 0.75, D(G(z)): 0.24
# Epoch [46/110], Step [600/600], d_loss: 1.0043, g_loss: 2.2304, D(x): 0.73, D(G(z)): 0.32
# Saving fake_images-0047.png
# Epoch [47/110], Step [200/600], d_loss: 0.6952, g_loss: 2.8433, D(x): 0.75, D(G(z)): 0.19
# Epoch [47/110], Step [400/600], d_loss: 1.0197, g_loss: 1.5366, D(x): 0.73, D(G(z)): 0.34
# Epoch [47/110], Step [600/600], d_loss: 0.7601, g_loss: 2.2434, D(x): 0.71, D(G(z)): 0.19
# Saving fake_images-0048.png
# Epoch [48/110], Step [200/600], d_loss: 1.0965, g_loss: 1.3771, D(x): 0.59, D(G(z)): 0.19
# Epoch [48/110], Step [400/600], d_loss: 0.6682, g_loss: 1.8066, D(x): 0.78, D(G(z)): 0.21
# Epoch [48/110], Step [600/600], d_loss: 0.7385, g_loss: 2.2653, D(x): 0.73, D(G(z)): 0.23
# Saving fake_images-0049.png
# Epoch [49/110], Step [200/600], d_loss: 0.7309, g_loss: 2.2413, D(x): 0.82, D(G(z)): 0.32
# Epoch [49/110], Step [400/600], d_loss: 0.8085, g_loss: 1.5427, D(x): 0.73, D(G(z)): 0.28
# Epoch [49/110], Step [600/600], d_loss: 0.8919, g_loss: 2.0958, D(x): 0.76, D(G(z)): 0.35
# Saving fake_images-0050.png
# Epoch [50/110], Step [200/600], d_loss: 0.7078, g_loss: 2.2813, D(x): 0.74, D(G(z)): 0.19
# Epoch [50/110], Step [400/600], d_loss: 0.5282, g_loss: 1.9089, D(x): 0.78, D(G(z)): 0.17
# Epoch [50/110], Step [600/600], d_loss: 0.6578, g_loss: 2.1102, D(x): 0.76, D(G(z)): 0.20
# Saving fake_images-0051.png
# Epoch [51/110], Step [200/600], d_loss: 0.6082, g_loss: 2.6991, D(x): 0.80, D(G(z)): 0.22
# Epoch [51/110], Step [400/600], d_loss: 0.8794, g_loss: 1.8438, D(x): 0.74, D(G(z)): 0.31
# Epoch [51/110], Step [600/600], d_loss: 0.6526, g_loss: 2.2086, D(x): 0.75, D(G(z)): 0.20
# Saving fake_images-0052.png
# Epoch [52/110], Step [200/600], d_loss: 0.9809, g_loss: 1.7562, D(x): 0.78, D(G(z)): 0.39
# Epoch [52/110], Step [400/600], d_loss: 0.7066, g_loss: 2.1741, D(x): 0.81, D(G(z)): 0.30
# Epoch [52/110], Step [600/600], d_loss: 0.8017, g_loss: 2.1771, D(x): 0.70, D(G(z)): 0.17
# Saving fake_images-0053.png
# Epoch [53/110], Step [200/600], d_loss: 0.8981, g_loss: 2.1369, D(x): 0.70, D(G(z)): 0.26
# Epoch [53/110], Step [400/600], d_loss: 0.6021, g_loss: 1.7809, D(x): 0.85, D(G(z)): 0.27
# Epoch [53/110], Step [600/600], d_loss: 0.9870, g_loss: 1.8378, D(x): 0.79, D(G(z)): 0.37
# Saving fake_images-0054.png
# Epoch [54/110], Step [200/600], d_loss: 0.6481, g_loss: 1.5533, D(x): 0.80, D(G(z)): 0.25
# Epoch [54/110], Step [400/600], d_loss: 0.5401, g_loss: 1.8161, D(x): 0.81, D(G(z)): 0.19
# Epoch [54/110], Step [600/600], d_loss: 0.7535, g_loss: 2.1849, D(x): 0.71, D(G(z)): 0.19
# Saving fake_images-0055.png
# Epoch [55/110], Step [200/600], d_loss: 0.8424, g_loss: 1.4707, D(x): 0.79, D(G(z)): 0.32
# Epoch [55/110], Step [400/600], d_loss: 1.1124, g_loss: 2.0402, D(x): 0.75, D(G(z)): 0.38
# Epoch [55/110], Step [600/600], d_loss: 1.1346, g_loss: 1.1162, D(x): 0.67, D(G(z)): 0.34
# Saving fake_images-0056.png
# Epoch [56/110], Step [200/600], d_loss: 0.9800, g_loss: 2.3311, D(x): 0.66, D(G(z)): 0.25
# Epoch [56/110], Step [400/600], d_loss: 1.1013, g_loss: 1.3242, D(x): 0.74, D(G(z)): 0.37
# Epoch [56/110], Step [600/600], d_loss: 0.7495, g_loss: 1.6542, D(x): 0.79, D(G(z)): 0.29
# Saving fake_images-0057.png
# Epoch [57/110], Step [200/600], d_loss: 0.6877, g_loss: 1.7192, D(x): 0.76, D(G(z)): 0.25
# Epoch [57/110], Step [400/600], d_loss: 0.8194, g_loss: 2.2325, D(x): 0.67, D(G(z)): 0.18
# Epoch [57/110], Step [600/600], d_loss: 0.8010, g_loss: 1.9055, D(x): 0.74, D(G(z)): 0.27
# Saving fake_images-0058.png
# Epoch [58/110], Step [200/600], d_loss: 0.8072, g_loss: 1.9583, D(x): 0.69, D(G(z)): 0.25
# Epoch [58/110], Step [400/600], d_loss: 0.8202, g_loss: 1.8272, D(x): 0.75, D(G(z)): 0.28
# Epoch [58/110], Step [600/600], d_loss: 0.8316, g_loss: 2.3793, D(x): 0.81, D(G(z)): 0.33
# Saving fake_images-0059.png
# Epoch [59/110], Step [200/600], d_loss: 0.7961, g_loss: 1.8944, D(x): 0.69, D(G(z)): 0.18
# Epoch [59/110], Step [400/600], d_loss: 0.8682, g_loss: 2.0152, D(x): 0.73, D(G(z)): 0.28
# Epoch [59/110], Step [600/600], d_loss: 0.5865, g_loss: 2.2680, D(x): 0.82, D(G(z)): 0.23
# Saving fake_images-0060.png
# Epoch [60/110], Step [200/600], d_loss: 0.7571, g_loss: 1.7636, D(x): 0.71, D(G(z)): 0.20
# Epoch [60/110], Step [400/600], d_loss: 1.0133, g_loss: 2.1727, D(x): 0.64, D(G(z)): 0.23
# Epoch [60/110], Step [600/600], d_loss: 0.8106, g_loss: 2.3086, D(x): 0.78, D(G(z)): 0.31
# Saving fake_images-0061.png
# Epoch [61/110], Step [200/600], d_loss: 0.8062, g_loss: 1.7999, D(x): 0.74, D(G(z)): 0.25
# Epoch [61/110], Step [400/600], d_loss: 1.1123, g_loss: 1.9408, D(x): 0.67, D(G(z)): 0.27
# Epoch [61/110], Step [600/600], d_loss: 0.6484, g_loss: 1.8195, D(x): 0.76, D(G(z)): 0.24
# Saving fake_images-0062.png
# Epoch [62/110], Step [200/600], d_loss: 0.8761, g_loss: 2.3473, D(x): 0.72, D(G(z)): 0.26
# Epoch [62/110], Step [400/600], d_loss: 0.6642, g_loss: 1.8793, D(x): 0.78, D(G(z)): 0.22
# Epoch [62/110], Step [600/600], d_loss: 0.7516, g_loss: 2.0309, D(x): 0.79, D(G(z)): 0.30
# Saving fake_images-0063.png
# Epoch [63/110], Step [200/600], d_loss: 0.8192, g_loss: 1.6000, D(x): 0.77, D(G(z)): 0.27
# Epoch [63/110], Step [400/600], d_loss: 0.8365, g_loss: 1.9143, D(x): 0.70, D(G(z)): 0.24
# Epoch [63/110], Step [600/600], d_loss: 1.0620, g_loss: 1.3025, D(x): 0.70, D(G(z)): 0.33
# Saving fake_images-0064.png
# Epoch [64/110], Step [200/600], d_loss: 0.8177, g_loss: 2.2765, D(x): 0.73, D(G(z)): 0.25
# Epoch [64/110], Step [400/600], d_loss: 0.7944, g_loss: 2.1498, D(x): 0.76, D(G(z)): 0.30
# Epoch [64/110], Step [600/600], d_loss: 0.9091, g_loss: 1.8536, D(x): 0.66, D(G(z)): 0.22
# Saving fake_images-0065.png
# Epoch [65/110], Step [200/600], d_loss: 0.7313, g_loss: 2.0008, D(x): 0.76, D(G(z)): 0.25
# Epoch [65/110], Step [400/600], d_loss: 0.8324, g_loss: 1.6361, D(x): 0.68, D(G(z)): 0.23
# Epoch [65/110], Step [600/600], d_loss: 0.9203, g_loss: 1.7245, D(x): 0.77, D(G(z)): 0.35
# Saving fake_images-0066.png
# Epoch [66/110], Step [200/600], d_loss: 0.7571, g_loss: 1.8157, D(x): 0.71, D(G(z)): 0.19
# Epoch [66/110], Step [400/600], d_loss: 0.7108, g_loss: 2.1665, D(x): 0.84, D(G(z)): 0.31
# Epoch [66/110], Step [600/600], d_loss: 0.6921, g_loss: 1.7092, D(x): 0.76, D(G(z)): 0.22
# Saving fake_images-0067.png
# Epoch [67/110], Step [200/600], d_loss: 1.0004, g_loss: 2.2048, D(x): 0.70, D(G(z)): 0.25
# Epoch [67/110], Step [400/600], d_loss: 0.6557, g_loss: 1.5452, D(x): 0.83, D(G(z)): 0.30
# Epoch [67/110], Step [600/600], d_loss: 0.8227, g_loss: 1.7596, D(x): 0.70, D(G(z)): 0.24
# Saving fake_images-0068.png
# Epoch [68/110], Step [200/600], d_loss: 0.7177, g_loss: 2.0884, D(x): 0.82, D(G(z)): 0.31
# Epoch [68/110], Step [400/600], d_loss: 0.8127, g_loss: 1.9277, D(x): 0.76, D(G(z)): 0.25
# Epoch [68/110], Step [600/600], d_loss: 0.5914, g_loss: 2.0332, D(x): 0.76, D(G(z)): 0.17
# Saving fake_images-0069.png
# Epoch [69/110], Step [200/600], d_loss: 0.7427, g_loss: 2.5843, D(x): 0.71, D(G(z)): 0.19
# Epoch [69/110], Step [400/600], d_loss: 0.5793, g_loss: 1.5884, D(x): 0.82, D(G(z)): 0.24
# Epoch [69/110], Step [600/600], d_loss: 0.9564, g_loss: 1.7039, D(x): 0.61, D(G(z)): 0.17
# Saving fake_images-0070.png
# Epoch [70/110], Step [200/600], d_loss: 0.9277, g_loss: 2.3243, D(x): 0.76, D(G(z)): 0.32
# Epoch [70/110], Step [400/600], d_loss: 0.8196, g_loss: 2.2197, D(x): 0.76, D(G(z)): 0.30
# Epoch [70/110], Step [600/600], d_loss: 0.7806, g_loss: 2.0875, D(x): 0.73, D(G(z)): 0.25
# Saving fake_images-0071.png
# Epoch [71/110], Step [200/600], d_loss: 0.5850, g_loss: 1.8921, D(x): 0.83, D(G(z)): 0.25
# Epoch [71/110], Step [400/600], d_loss: 0.8914, g_loss: 2.1256, D(x): 0.65, D(G(z)): 0.18
# Epoch [71/110], Step [600/600], d_loss: 0.6433, g_loss: 1.8267, D(x): 0.80, D(G(z)): 0.26
# Saving fake_images-0072.png
# Epoch [72/110], Step [200/600], d_loss: 0.8205, g_loss: 2.0442, D(x): 0.69, D(G(z)): 0.23
# Epoch [72/110], Step [400/600], d_loss: 0.7405, g_loss: 1.8098, D(x): 0.83, D(G(z)): 0.34
# Epoch [72/110], Step [600/600], d_loss: 0.8546, g_loss: 1.9085, D(x): 0.69, D(G(z)): 0.22
# Saving fake_images-0073.png
# Epoch [73/110], Step [200/600], d_loss: 0.8716, g_loss: 1.5077, D(x): 0.72, D(G(z)): 0.26
# Epoch [73/110], Step [400/600], d_loss: 0.8181, g_loss: 1.8861, D(x): 0.76, D(G(z)): 0.32
# Epoch [73/110], Step [600/600], d_loss: 0.9357, g_loss: 1.9498, D(x): 0.74, D(G(z)): 0.30
# Saving fake_images-0074.png
# Epoch [74/110], Step [200/600], d_loss: 0.8782, g_loss: 1.5742, D(x): 0.70, D(G(z)): 0.29
# Epoch [74/110], Step [400/600], d_loss: 0.9415, g_loss: 1.4010, D(x): 0.68, D(G(z)): 0.29
# Epoch [74/110], Step [600/600], d_loss: 0.7915, g_loss: 1.9700, D(x): 0.70, D(G(z)): 0.23
# Saving fake_images-0075.png
# Epoch [75/110], Step [200/600], d_loss: 1.0505, g_loss: 1.6208, D(x): 0.62, D(G(z)): 0.23
# Epoch [75/110], Step [400/600], d_loss: 0.7427, g_loss: 1.8706, D(x): 0.72, D(G(z)): 0.20
# Epoch [75/110], Step [600/600], d_loss: 0.7671, g_loss: 2.1094, D(x): 0.73, D(G(z)): 0.25
# Saving fake_images-0076.png
# Epoch [76/110], Step [200/600], d_loss: 0.7798, g_loss: 1.9336, D(x): 0.69, D(G(z)): 0.21
# Epoch [76/110], Step [400/600], d_loss: 0.7865, g_loss: 2.0059, D(x): 0.76, D(G(z)): 0.26
# Epoch [76/110], Step [600/600], d_loss: 0.9370, g_loss: 1.7609, D(x): 0.62, D(G(z)): 0.21
# Saving fake_images-0077.png
# Epoch [77/110], Step [200/600], d_loss: 1.0426, g_loss: 1.3040, D(x): 0.72, D(G(z)): 0.38
# Epoch [77/110], Step [400/600], d_loss: 0.8494, g_loss: 1.8200, D(x): 0.73, D(G(z)): 0.26
# Epoch [77/110], Step [600/600], d_loss: 0.8605, g_loss: 1.3739, D(x): 0.84, D(G(z)): 0.38
# Saving fake_images-0078.png
# Epoch [78/110], Step [200/600], d_loss: 0.9384, g_loss: 1.7521, D(x): 0.71, D(G(z)): 0.30
# Epoch [78/110], Step [400/600], d_loss: 0.7922, g_loss: 1.7627, D(x): 0.73, D(G(z)): 0.28
# Epoch [78/110], Step [600/600], d_loss: 0.9509, g_loss: 1.3660, D(x): 0.63, D(G(z)): 0.23
# Saving fake_images-0079.png
# Epoch [79/110], Step [200/600], d_loss: 0.8973, g_loss: 1.2456, D(x): 0.75, D(G(z)): 0.35
# Epoch [79/110], Step [400/600], d_loss: 1.0524, g_loss: 1.8351, D(x): 0.67, D(G(z)): 0.32
# Epoch [79/110], Step [600/600], d_loss: 1.0406, g_loss: 2.0087, D(x): 0.71, D(G(z)): 0.35
# Saving fake_images-0080.png
# Epoch [80/110], Step [200/600], d_loss: 0.8568, g_loss: 1.3361, D(x): 0.80, D(G(z)): 0.36
# Epoch [80/110], Step [400/600], d_loss: 0.8690, g_loss: 1.9574, D(x): 0.80, D(G(z)): 0.35
# Epoch [80/110], Step [600/600], d_loss: 0.8184, g_loss: 1.7415, D(x): 0.76, D(G(z)): 0.31
# Saving fake_images-0081.png
# Epoch [81/110], Step [200/600], d_loss: 0.6941, g_loss: 1.8392, D(x): 0.76, D(G(z)): 0.24
# Epoch [81/110], Step [400/600], d_loss: 0.8698, g_loss: 2.2620, D(x): 0.65, D(G(z)): 0.16
# Epoch [81/110], Step [600/600], d_loss: 0.8022, g_loss: 2.0652, D(x): 0.75, D(G(z)): 0.24
# Saving fake_images-0082.png
# Epoch [82/110], Step [200/600], d_loss: 0.8958, g_loss: 1.4939, D(x): 0.78, D(G(z)): 0.35
# Epoch [82/110], Step [400/600], d_loss: 0.9928, g_loss: 1.6004, D(x): 0.65, D(G(z)): 0.30
# Epoch [82/110], Step [600/600], d_loss: 0.6449, g_loss: 2.0952, D(x): 0.77, D(G(z)): 0.20
# Saving fake_images-0083.png
# Epoch [83/110], Step [200/600], d_loss: 0.9968, g_loss: 1.9331, D(x): 0.66, D(G(z)): 0.26
# Epoch [83/110], Step [400/600], d_loss: 0.9056, g_loss: 1.6478, D(x): 0.73, D(G(z)): 0.30
# Epoch [83/110], Step [600/600], d_loss: 0.9570, g_loss: 1.5133, D(x): 0.70, D(G(z)): 0.32
# Saving fake_images-0084.png
# Epoch [84/110], Step [200/600], d_loss: 0.6669, g_loss: 1.9152, D(x): 0.81, D(G(z)): 0.28
# Epoch [84/110], Step [400/600], d_loss: 1.0165, g_loss: 1.2274, D(x): 0.70, D(G(z)): 0.37
# Epoch [84/110], Step [600/600], d_loss: 1.0554, g_loss: 1.7082, D(x): 0.67, D(G(z)): 0.31
# Saving fake_images-0085.png
# Epoch [85/110], Step [200/600], d_loss: 1.1960, g_loss: 1.6097, D(x): 0.55, D(G(z)): 0.21
# Epoch [85/110], Step [400/600], d_loss: 0.9895, g_loss: 1.6891, D(x): 0.69, D(G(z)): 0.32
# Epoch [85/110], Step [600/600], d_loss: 0.8340, g_loss: 2.1508, D(x): 0.67, D(G(z)): 0.22
# Saving fake_images-0086.png
# Epoch [86/110], Step [200/600], d_loss: 0.8664, g_loss: 1.3948, D(x): 0.76, D(G(z)): 0.32
# Epoch [86/110], Step [400/600], d_loss: 0.8907, g_loss: 1.7248, D(x): 0.70, D(G(z)): 0.29
# Epoch [86/110], Step [600/600], d_loss: 0.9814, g_loss: 2.1715, D(x): 0.66, D(G(z)): 0.28
# Saving fake_images-0087.png
# Epoch [87/110], Step [200/600], d_loss: 0.8123, g_loss: 2.2843, D(x): 0.75, D(G(z)): 0.30
# Epoch [87/110], Step [400/600], d_loss: 0.7911, g_loss: 1.9398, D(x): 0.71, D(G(z)): 0.24
# Epoch [87/110], Step [600/600], d_loss: 0.9346, g_loss: 1.8866, D(x): 0.74, D(G(z)): 0.35
# Saving fake_images-0088.png
# Epoch [88/110], Step [200/600], d_loss: 0.8807, g_loss: 2.0446, D(x): 0.68, D(G(z)): 0.23
# Epoch [88/110], Step [400/600], d_loss: 0.7817, g_loss: 1.5487, D(x): 0.75, D(G(z)): 0.28
# Epoch [88/110], Step [600/600], d_loss: 0.9227, g_loss: 1.3862, D(x): 0.74, D(G(z)): 0.34
# Saving fake_images-0089.png
# Epoch [89/110], Step [200/600], d_loss: 0.9996, g_loss: 1.2613, D(x): 0.76, D(G(z)): 0.40
# Epoch [89/110], Step [400/600], d_loss: 0.9320, g_loss: 1.7322, D(x): 0.67, D(G(z)): 0.29
# Epoch [89/110], Step [600/600], d_loss: 0.9023, g_loss: 1.5981, D(x): 0.67, D(G(z)): 0.28
# Saving fake_images-0090.png
# Epoch [90/110], Step [200/600], d_loss: 0.8294, g_loss: 1.9059, D(x): 0.78, D(G(z)): 0.33
# Epoch [90/110], Step [400/600], d_loss: 1.0138, g_loss: 1.5114, D(x): 0.70, D(G(z)): 0.37
# Epoch [90/110], Step [600/600], d_loss: 1.0016, g_loss: 1.7676, D(x): 0.67, D(G(z)): 0.31
# Saving fake_images-0091.png
# Epoch [91/110], Step [200/600], d_loss: 0.8802, g_loss: 1.1003, D(x): 0.78, D(G(z)): 0.34
# Epoch [91/110], Step [400/600], d_loss: 0.8842, g_loss: 1.6409, D(x): 0.77, D(G(z)): 0.32
# Epoch [91/110], Step [600/600], d_loss: 0.8574, g_loss: 1.8384, D(x): 0.69, D(G(z)): 0.25
# Saving fake_images-0092.png
# Epoch [92/110], Step [200/600], d_loss: 0.8614, g_loss: 1.6970, D(x): 0.74, D(G(z)): 0.32
# Epoch [92/110], Step [400/600], d_loss: 1.1261, g_loss: 1.4889, D(x): 0.64, D(G(z)): 0.33
# Epoch [92/110], Step [600/600], d_loss: 0.8571, g_loss: 1.5808, D(x): 0.80, D(G(z)): 0.38
# Saving fake_images-0093.png
# Epoch [93/110], Step [200/600], d_loss: 1.0134, g_loss: 1.3474, D(x): 0.75, D(G(z)): 0.40
# Epoch [93/110], Step [400/600], d_loss: 0.9294, g_loss: 1.8047, D(x): 0.66, D(G(z)): 0.25
# Epoch [93/110], Step [600/600], d_loss: 0.8247, g_loss: 1.6023, D(x): 0.69, D(G(z)): 0.26
# Saving fake_images-0094.png
# Epoch [94/110], Step [200/600], d_loss: 1.1276, g_loss: 1.3331, D(x): 0.70, D(G(z)): 0.39
# Epoch [94/110], Step [400/600], d_loss: 0.8049, g_loss: 1.8529, D(x): 0.72, D(G(z)): 0.25
# Epoch [94/110], Step [600/600], d_loss: 1.0751, g_loss: 1.4945, D(x): 0.75, D(G(z)): 0.40
# Saving fake_images-0095.png
# Epoch [95/110], Step [200/600], d_loss: 0.8279, g_loss: 1.3958, D(x): 0.75, D(G(z)): 0.32
# Epoch [95/110], Step [400/600], d_loss: 0.6080, g_loss: 1.7069, D(x): 0.81, D(G(z)): 0.24
# Epoch [95/110], Step [600/600], d_loss: 0.9299, g_loss: 1.7505, D(x): 0.69, D(G(z)): 0.29
# Saving fake_images-0096.png
# Epoch [96/110], Step [200/600], d_loss: 1.0635, g_loss: 1.6067, D(x): 0.72, D(G(z)): 0.40
# Epoch [96/110], Step [400/600], d_loss: 0.8405, g_loss: 1.4108, D(x): 0.69, D(G(z)): 0.26
# Epoch [96/110], Step [600/600], d_loss: 0.8718, g_loss: 1.5977, D(x): 0.77, D(G(z)): 0.34
# Saving fake_images-0097.png
# Epoch [97/110], Step [200/600], d_loss: 0.8791, g_loss: 1.7435, D(x): 0.71, D(G(z)): 0.25
# Epoch [97/110], Step [400/600], d_loss: 1.2637, g_loss: 1.5151, D(x): 0.62, D(G(z)): 0.38
# Epoch [97/110], Step [600/600], d_loss: 0.9565, g_loss: 1.8456, D(x): 0.65, D(G(z)): 0.25
# Saving fake_images-0098.png
# Epoch [98/110], Step [200/600], d_loss: 0.7291, g_loss: 2.1476, D(x): 0.73, D(G(z)): 0.24
# Epoch [98/110], Step [400/600], d_loss: 0.9764, g_loss: 1.6190, D(x): 0.67, D(G(z)): 0.29
# Epoch [98/110], Step [600/600], d_loss: 0.8098, g_loss: 1.4825, D(x): 0.79, D(G(z)): 0.34
# Saving fake_images-0099.png
# Epoch [99/110], Step [200/600], d_loss: 0.9561, g_loss: 1.8126, D(x): 0.70, D(G(z)): 0.28
# Epoch [99/110], Step [400/600], d_loss: 0.7810, g_loss: 1.6417, D(x): 0.71, D(G(z)): 0.22
# Epoch [99/110], Step [600/600], d_loss: 0.8201, g_loss: 1.9492, D(x): 0.72, D(G(z)): 0.26
# Saving fake_images-0100.png
# Epoch [100/110], Step [200/600], d_loss: 1.0350, g_loss: 1.5753, D(x): 0.67, D(G(z)): 0.31
# Epoch [100/110], Step [400/600], d_loss: 0.8553, g_loss: 1.6248, D(x): 0.71, D(G(z)): 0.27
# Epoch [100/110], Step [600/600], d_loss: 0.7738, g_loss: 1.8946, D(x): 0.68, D(G(z)): 0.19
# Saving fake_images-0101.png
# Epoch [101/110], Step [200/600], d_loss: 0.8866, g_loss: 1.7474, D(x): 0.78, D(G(z)): 0.31
# Epoch [101/110], Step [400/600], d_loss: 0.9424, g_loss: 1.5095, D(x): 0.68, D(G(z)): 0.28
# Epoch [101/110], Step [600/600], d_loss: 0.8498, g_loss: 1.2449, D(x): 0.72, D(G(z)): 0.32
# Saving fake_images-0102.png
# Epoch [102/110], Step [200/600], d_loss: 0.9289, g_loss: 1.4638, D(x): 0.62, D(G(z)): 0.21
# Epoch [102/110], Step [400/600], d_loss: 0.8783, g_loss: 1.9156, D(x): 0.71, D(G(z)): 0.30
# Epoch [102/110], Step [600/600], d_loss: 0.8195, g_loss: 1.6109, D(x): 0.71, D(G(z)): 0.27
# Saving fake_images-0103.png
# Epoch [103/110], Step [200/600], d_loss: 0.9081, g_loss: 1.4609, D(x): 0.73, D(G(z)): 0.32
# Epoch [103/110], Step [400/600], d_loss: 0.8655, g_loss: 1.8577, D(x): 0.74, D(G(z)): 0.31
# Epoch [103/110], Step [600/600], d_loss: 1.1423, g_loss: 1.6258, D(x): 0.68, D(G(z)): 0.37
# Saving fake_images-0104.png
# Epoch [104/110], Step [200/600], d_loss: 0.9749, g_loss: 1.2956, D(x): 0.72, D(G(z)): 0.35
# Epoch [104/110], Step [400/600], d_loss: 0.9334, g_loss: 1.6294, D(x): 0.78, D(G(z)): 0.37
# Epoch [104/110], Step [600/600], d_loss: 0.7760, g_loss: 1.2573, D(x): 0.71, D(G(z)): 0.25
# Saving fake_images-0105.png
# Epoch [105/110], Step [200/600], d_loss: 1.1185, g_loss: 1.1004, D(x): 0.72, D(G(z)): 0.41
# Epoch [105/110], Step [400/600], d_loss: 1.0705, g_loss: 1.1814, D(x): 0.69, D(G(z)): 0.36
# Epoch [105/110], Step [600/600], d_loss: 0.8865, g_loss: 1.7248, D(x): 0.65, D(G(z)): 0.23
# Saving fake_images-0106.png
# Epoch [106/110], Step [200/600], d_loss: 0.9385, g_loss: 1.3231, D(x): 0.71, D(G(z)): 0.32
# Epoch [106/110], Step [400/600], d_loss: 0.7568, g_loss: 1.5584, D(x): 0.74, D(G(z)): 0.27
# Epoch [106/110], Step [600/600], d_loss: 1.1713, g_loss: 1.5632, D(x): 0.65, D(G(z)): 0.36
# Saving fake_images-0107.png
# Epoch [107/110], Step [200/600], d_loss: 0.8134, g_loss: 1.7030, D(x): 0.68, D(G(z)): 0.23
# Epoch [107/110], Step [400/600], d_loss: 1.0865, g_loss: 1.4428, D(x): 0.77, D(G(z)): 0.41
# Epoch [107/110], Step [600/600], d_loss: 0.9466, g_loss: 2.0144, D(x): 0.63, D(G(z)): 0.24
# Saving fake_images-0108.png
# Epoch [108/110], Step [200/600], d_loss: 1.2253, g_loss: 1.3653, D(x): 0.73, D(G(z)): 0.46
# Epoch [108/110], Step [400/600], d_loss: 0.9590, g_loss: 1.4944, D(x): 0.68, D(G(z)): 0.33
# Epoch [108/110], Step [600/600], d_loss: 0.8166, g_loss: 2.0154, D(x): 0.73, D(G(z)): 0.28
# Saving fake_images-0109.png
# Epoch [109/110], Step [200/600], d_loss: 0.9660, g_loss: 1.4600, D(x): 0.73, D(G(z)): 0.36
# Epoch [109/110], Step [400/600], d_loss: 0.9990, g_loss: 1.1494, D(x): 0.69, D(G(z)): 0.33
# Epoch [109/110], Step [600/600], d_loss: 0.8815, g_loss: 1.5167, D(x): 0.66, D(G(z)): 0.24
# Saving fake_images-0110.png
# CPU times: user 52min 52s, sys: 5.54 s, total: 52min 57s
# Wall time: 53min 18s

# %% [markdown]
# Now that we have trained the models, we can save checkpoints.

# %%
# Save the model checkpoints
torch.save(G.state_dict(), 'G.ckpt')
torch.save(D.state_dict(), 'D.ckpt')

# %% [markdown]
# **Here's how the generated images look, after the 10th, 50th and 100th epochs of training.**

# %%
Image('./samples/fake_images-0010.png')

# %%
Image('./samples/fake_images-0050.png')

# %%
Image('./samples/fake_images-0100.png')

# %% [markdown]
# **We can visualize the training process by combining the sample images generated after each epoch into a video using OpenCV.**

# %%
import cv2
import os
from IPython.display import FileLink

vid_fname = 'gans_training.avi'

files = [os.path.join(sample_dir, f) for f in os.listdir(sample_dir) if 'fake_images' in f]
files.sort()

out = cv2.VideoWriter(vid_fname,cv2.VideoWriter_fourcc(*'MP4V'), 8, (302,302))
[out.write(cv2.imread(fname)) for fname in files]
out.release()
FileLink('gans_training.avi')
# Out:
# /content/gans_training.avi

# %% [markdown]
# **We can also visualize how the loss changes over time. Visualizing losses is quite useful for debugging the training process. For GANs, we expect the generator's loss to reduce over time, without the discriminator's loss getting too high.**

# %%
plt.plot(d_losses, '-')
plt.plot(g_losses, '-')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['Discriminator', 'Generator'])
plt.title('Losses');

# %%
plt.plot(real_scores, '-')
plt.plot(fake_scores, '-')
plt.xlabel('epoch')
plt.ylabel('score')
plt.legend(['Real Score', 'Fake score'])
plt.title('Scores');
